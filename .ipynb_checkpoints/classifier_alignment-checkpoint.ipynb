# %%
import warnings
warnings.simplefilter('ignore')
import sys
sys.path.append('/home1/jrudoler/src/')
import cmlreaders as cml
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
# plt.rcParams['savefig.facecolor']='white'
import seaborn as sns
import pandas as pd
pd.options.display.max_rows = 50
pd.options.display.max_columns = None
from pd_to_pb import pandas_to_pybeh as pb
import scipy as scp
plt.rcParams['axes.labelsize'] = 16
from classifier_io import ClassifierModel
import pickle
sns.set_palette('twilight')
import cmldask.CMLDask as da
from nicls_helpers import *

subject_list = np.loadtxt("final_subject_list.txt", dtype=str)

# %%
client = da.new_dask_client_sge("nicls_analysis",
                            "2GB",
                           log_directory='/home1/jrudoler/logs/')
# Out:
# Unique port for jrudoler is 51360
# {'dashboard_address': ':51360'}
# To view the dashboard, run:
# `ssh -fN jrudoler@rhino2.psych.upenn.edu -L 8000:192.168.86.106:51360` in your local computer's terminal (NOT rhino)
# and then navigate to localhost:8000 in your browser

# %%
cl_data = cml.get_data_index(kind = 'ltp');
cl_data = cl_data[cl_data['experiment'] == 'NiclsCourierClosedLoop']
# Subjects with good classification protocol and low recall
cl_data = cl_data.query("subject in @subject_list")

# %%
def load_merged_events(dr):
    read = cml.CMLReader(subject=dr['subject'], experiment=dr['experiment'], session=dr['session'], montage=0, localization=0)
    evs = read.load('task_events')
    evs.drop(index=evs[evs.type.str.contains('VV')].index, inplace=True)
    evs.drop(index=evs.query("phase in ['practice', 'movie', 'video']").index, inplace=True)
    
    res = evs.groupby(['subject','session', 'trial']).agg({'classifier':lambda x: list(np.unique([i for i in x if i!='X'])) or 'NoStim'})
    res = res.apply(lambda x: [i if isinstance(i, str) else i[0] for i in x])

    evs['trial_type']=''
    for (subject, session, trial), row in res.iterrows():
        idx = evs.query(f"subject=='{subject}' & session=={session} & trial=={trial}").index
        evs['trial_type'][idx] = [row['classifier']]*len(idx)
    evs = evs[['eegoffset','mstime', 'classifier', 'type', 'item', 'itemno', 
               'phase', 'session', 'trial', 'trial_type', 'subject', 'experiment', 'eegfile', 'store', 'recalled']].sort_values("mstime")
    # merge with logs that have extended classifier info 
    log = pd.read_json(f"/data/eeg/scalp/ltp/NiclsCourierClosedLoop/{dr['subject']}/session_{dr['session']}/session.jsonl", lines=True)
#     classifier_result = epoch.merge(classifier_result, on="id", suffixes=["_eeg_epoch", "_class_result"])
#     ## using task pc clock, to match with unity events,
#     classifier_result['time_eeg_epoch'] = pd.to_datetime(classifier_result['task pc time_eeg_epoch']).map(pd.Timestamp.timestamp)*1000
#     classifier_result['time_class_result'] = pd.to_datetime(classifier_result['task pc time_class_result']).map(pd.Timestamp.timestamp)*1000
#     classifier_result = classifier_result[['id', 'time_eeg_epoch', 'time_class_result', 
#                                            "eeg collection duration", "classifier duration", 
#                                            "normalized", "result", "probability"]].convert_dtypes({"id":int}).set_index("id")
#     classifier_result = classifier_result.astype({"time_class_result":'int64', "time_eeg_epoch":'int64'}).sort_values('time_class_result')
    networks = log.query("type == 'network'")['data'].apply(pd.Series)
    networks['sent'] = networks['sent'].apply(eval)
    messages = networks.query("~sent")['message'].apply(pd.Series)
    # load epoch and result events, replace time with outermost time in logs (should match mstime)
    epoch = pd.concat([messages.query("type=='EEG_EPOCH_END'").drop(columns="data"),
                       messages.query("type=='EEG_EPOCH_END'")['data'].apply(pd.Series)], axis=1).drop(columns='time')
    epoch = pd.concat([epoch, log.loc[epoch.index]['time']], axis=1)
    classifier_result = pd.concat([messages.query("type=='CLASSIFIER_RESULT'").drop(columns="data"),
                                  messages.query("type=='CLASSIFIER_RESULT'")['data'].apply(pd.Series)], axis=1).drop(columns='time')
    classifier_result = pd.concat([classifier_result, log.loc[classifier_result.index]['time']], axis=1)
    classifier_result = epoch.merge(classifier_result, on="id", suffixes=["_eeg_epoch", "_class_result"])
    # classifier_result['time_eeg_epoch'] = pd.to_datetime(classifier_result['time_eeg_epoch']).map(pd.Timestamp.timestamp)*1000
    # classifier_result['time_class_result'] = pd.to_datetime(classifier_result['time_class_result']).map(pd.Timestamp.timestamp)*1000
    classifier_result = classifier_result[['id', 'time_eeg_epoch', 'time_class_result', 
                                           "eeg collection duration", "classifier duration", 
                                           "normalized", "result", "probability"]]

    classifier_result['type'] = 'CLASSIFIER'
    classifier_result = classifier_result.astype({"time_class_result":'int64', "time_eeg_epoch":'int64', "id":'int64'}).sort_values('time_class_result')
    merged_events = pd.merge_asof(
        evs,
        classifier_result, 
        left_on='mstime', right_on='time_class_result',
        tolerance=100, direction='nearest', by='type'
    )
    
    return merged_events, classifier_result

# %%
futures = []
for i, row in cl_data.iterrows():
    futures.append(client.submit(load_merged_events, row))

# %%
client.shutdown()
# Out:
# 2023-02-14 10:45:42,667 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client

# %%
from dask.distributed import progress
progress(futures)
# Out:
# VBox()

# %%
results = client.gather(futures)

# %%
CL_evs = pd.concat([r[0] for r in results]).sort_values(by=["subject", "session", "mstime", "type"])
CL_evs = CL_evs.reset_index(drop=True)
for i, row in CL_evs.iterrows():
    if i+1 < len(CL_evs):
        CL_evs.at[i, 'next_type'] = CL_evs.at[i+1, 'type']
        CL_evs.at[i+1, 'prev_type'] = CL_evs.at[i, 'type']
    if row["type"] in ['CLASSIFIER', 'TIMEOUT']:
        CL_evs.at[i, 'item'] = CL_evs.at[i+1, 'item']
        CL_evs.at[i, 'recalled'] = CL_evs.at[i+1, 'recalled']
        CL_evs.at[i, 'store'] = CL_evs.at[i+1, 'store']
        if CL_evs.at[i+1, 'type']=='WORD':
            CL_evs.at[i+1, 'probability'] = row["probability"]
            CL_evs.at[i+1, 'wait_time'] = row["probability"]
    else:
        continue
class_idx = CL_evs.query("type=='CLASSIFIER'").index
CL_evs.loc[class_idx, "orig_eegoffset"] = CL_evs.loc[class_idx, "eegoffset"]
CL_evs.loc[class_idx, "eegoffset"] = CL_evs.loc[class_idx, 'eegoffset'] - (
    (CL_evs['time_class_result'] - CL_evs['time_eeg_epoch'])
)
CL_evs.to_csv("processed_events_NiclsCourierClosedLoop.csv")

# %%
CL_evs.query("type=='WORD'").groupby(["subject", "session", "trial_type"]).agg({"recalled":"mean", "probability":"mean"})
# Out:
#                             recalled  probability
# subject session trial_type
# LTP462  0       Neg         0.333333     0.485012
#                 NoStim      0.633333          NaN
#                 Pos         0.666667     0.504499
#                 Sham        0.300000     0.487880
#         1       Neg         0.622222     0.485941
# ...                              ...          ...
# LTP500  2       Sham        0.600000     0.671470
#         3       Neg         0.777778     0.174701
#                 NoStim      0.833333          NaN
#                 Pos         0.688889     0.946089
#                 Sham        0.633333     0.933399
#
# [272 rows x 2 columns]

# %%
CL_evs.query("trial_type=='Pos' and type=='WORD'")["probability"].quantile([.01, .95])
# Out:
# 0.01    0.497966
# 0.95    1.000000
# Name: probability, dtype: float64

# %% [markdown]
# ## Load processed events

# %%
CL_evs = pd.read_csv("processed_events_NiclsCourierClosedLoop.csv", index_col=0)

# %%
CL_evs.query("type in ['CLASSIFIER', 'CLASSIFIER_WAIT', 'TIMEOUT'] and session==0 and subject=='LTP481' and trial==1")
# Out:
#         eegoffset         mstime classifier             type            item  \
# 37887  997420.000  1645730155781          X  CLASSIFIER_WAIT            -999
# 37888 1006620.000  1645730160380        Neg       CLASSIFIER           LEASH
# 37891 1049331.000  1645730181130          X  CLASSIFIER_WAIT            -999
# 37892 1048965.000  1645730181147        Neg       CLASSIFIER  ACTION_FIGURES
# 37894 1077729.000  1645730194997          X  CLASSIFIER_WAIT            -999
# ...           ...            ...        ...              ...             ...
# 38001 2096647.000  1645730692664        Neg       CLASSIFIER    CURLING_IRON
# 38005 2105547.000  1645730696897          X  CLASSIFIER_WAIT            -999
# 38006 2115751.000  1645730701880        Neg          TIMEOUT        NECKLACE
# 38010 2125478.000  1645730706630          X  CLASSIFIER_WAIT            -999
# 38011 2130400.000  1645730709130        Neg       CLASSIFIER       SAXOPHONE
#
#        itemno  phase  session  trial trial_type subject  \
# 37887    -999      1        0      1        Neg  LTP481
# 37888    -999      1        0      1        Neg  LTP481
# 37891    -999      1        0      1        Neg  LTP481
# 37892    -999      1        0      1        Neg  LTP481
# 37894    -999      1        0      1        Neg  LTP481
# ...       ...    ...      ...    ...        ...     ...
# 38001    -999      1        0      1        Neg  LTP481
# 38005    -999      1        0      1        Neg  LTP481
# 38006    -999      1        0      1        Neg  LTP481
# 38010    -999      1        0      1        Neg  LTP481
# 38011    -999      1        0      1        Neg  LTP481
#
#                    experiment  \
# 37887  NiclsCourierClosedLoop
# 37888  NiclsCourierClosedLoop
# 37891  NiclsCourierClosedLoop
# 37892  NiclsCourierClosedLoop
# 37894  NiclsCourierClosedLoop
# ...                       ...
# 38001  NiclsCourierClosedLoop
# 38005  NiclsCourierClosedLoop
# 38006  NiclsCourierClosedLoop
# 38010  NiclsCourierClosedLoop
# 38011  NiclsCourierClosedLoop
#
#                                                  eegfile          store  \
# 37887  /protocols/ltp/subjects/LTP481/experiments/Nic...           -999
# 37888  /protocols/ltp/subjects/LTP481/experiments/Nic...      pet_store
# 37891  /protocols/ltp/subjects/LTP481/experiments/Nic...           -999
# 37892  /protocols/ltp/subjects/LTP481/experiments/Nic...      toy_store
# 37894  /protocols/ltp/subjects/LTP481/experiments/Nic...           -999
# ...                                                  ...            ...
# 38001  /protocols/ltp/subjects/LTP481/experiments/Nic...    barber_shop
# 38005  /protocols/ltp/subjects/LTP481/experiments/Nic...           -999
# 38006  /protocols/ltp/subjects/LTP481/experiments/Nic...  jewelry_store
# 38010  /protocols/ltp/subjects/LTP481/experiments/Nic...           -999
# 38011  /protocols/ltp/subjects/LTP481/experiments/Nic...    music_store
#
#        recalled       id    time_eeg_epoch  time_class_result  \
# 37887      -999      NaN               NaN                NaN
# 37888         1 3866.000 1645730160157.000  1645730160375.000
# 37891      -999      NaN               NaN                NaN
# 37892         1 4031.000 1645730180743.000  1645730181144.000
# 37894      -999      NaN               NaN                NaN
# ...         ...      ...               ...                ...
# 38001      -999 8124.000 1645730692417.000  1645730692648.000
# 38005      -999      NaN               NaN                NaN
# 38006      -999      NaN               NaN                NaN
# 38010      -999      NaN               NaN                NaN
# 38011      -999 8256.000 1645730708926.000  1645730709124.000
#
#        eeg collection duration  classifier duration normalized  result  \
# 37887                      NaN                  NaN        NaN     NaN
# 37888                    2.000                0.218       True   0.000
# 37891                      NaN                  NaN        NaN     NaN
# 37892                    2.000                0.400       True   1.000
# 37894                      NaN                  NaN        NaN     NaN
# ...                        ...                  ...        ...     ...
# 38001                    2.000                0.229       True   0.000
# 38005                      NaN                  NaN        NaN     NaN
# 38006                      NaN                  NaN        NaN     NaN
# 38010                      NaN                  NaN        NaN     NaN
# 38011                    2.000                0.197       True   0.000
#
#        probability     next_type  orig_eegoffset
# 37887          NaN    CLASSIFIER             NaN
# 37888        0.468          WORD     1006838.000
# 37891          NaN    CLASSIFIER             NaN
# 37892        0.513          WORD     1049366.000
# 37894          NaN    CLASSIFIER             NaN
# ...            ...           ...             ...
# 38001        0.482  CUED_REC_CUE     2096878.000
# 38005          NaN       TIMEOUT             NaN
# 38006          NaN  CUED_REC_CUE             NaN
# 38010          NaN    CLASSIFIER             NaN
# 38011        0.479  CUED_REC_CUE     2130598.000
#
# [60 rows x 25 columns]

# %%
plt.figure(figsize=(8,4))
ax = sns.histplot(CL_evs.query("type=='WORD'"), x='probability', hue='trial_type', stat='count', bins=100, kde=True)
sns.move_legend(ax, 0, title="Trial Type")
plt.xlabel("Predicted Probability of Recall")
# plt.savefig("classifier_prediction_dist.pdf", dpi=200)
# Out:
# Text(0.5, 0, 'Predicted Probability of Recall')

# %%
log.loc[epoch.index]['data'].apply(pd.Series)['message'].apply(pd.Series)['time']
# Out:
# 25      1.646424e+09
# 27      1.646424e+09
# 28      1.646424e+09
# 30      1.646424e+09
# 33      1.646424e+09
#             ...
# 4987    1.646424e+09
# 4990    1.646424e+09
# 4992    1.646424e+09
# 4994    1.646424e+09
# 4998    1.646424e+09
# Name: time, Length: 1710, dtype: float64

# %%
merged_class_evs = merged_events.query("type=='CLASSIFIER'")
new_offsets = merged_class_evs['eegoffset'] - (merged_class_evs['time_class_result'] - merged_class_evs['time_eeg_epoch'])

# %%
CL_evs.query("type=='CLASSIFIER'")[CL_evs.query("type=='CLASSIFIER'")['classifier duration'].isna()]
# 97664    9155982  1651700092673        Neg  CLASSIFIER  -999    -999     2
# 97804    9986829  1651700498389        Pos  CLASSIFIER  -999    -999     2
#
#        session  trial trial_type subject store  recalled  time_eeg_epoch  \
# 858          0      6        Neg  LTP462  -999      -999             NaN
# 1776         1      2        Neg  LTP462  -999      -999             NaN
# 3260         0      3        Pos  LTP468  -999      -999             NaN
# 5307         1      6        Neg  LTP468  -999      -999             NaN
# 5310         1      6        Neg  LTP468  -999      -999             NaN
# 6340         0      3        Pos  LTP470  -999      -999             NaN
# 6392         0      3        Pos  LTP470  -999      -999             NaN
# 7718         1      3       Sham  LTP470  -999      -999             NaN
# 9254         0      2       Sham  LTP473  -999      -999             NaN
# 9699         0      4        Pos  LTP473  -999      -999             NaN
# 13107        0      4        Neg  LTP474  -999      -999             NaN
# 13540        0      7        Pos  LTP474  -999      -999             NaN
# 13653        0      7        Pos  LTP474  -999      -999             NaN
# 14445        1      3        Pos  LTP474  -999      -999             NaN
# 14640        1      4        Neg  LTP474  -999      -999             NaN
# 15589        0      1        Pos  LTP475  -999      -999             NaN
# 16023        0      4        Neg  LTP475  -999      -999             NaN
# 16655        0      8        Pos  LTP475  -999      -999             NaN
# 17985        1      6       Sham  LTP475  -999      -999             NaN
# 18081        1      6       Sham  LTP475  -999      -999             NaN
# 18943        0      1       Sham  LTP476  -999      -999             NaN
# 19047        0      2        Neg  LTP476  -999      -999             NaN
# 19895        0      8        Neg  LTP476  -999      -999             NaN
# 20678        1      3        Neg  LTP476  -999      -999             NaN
# 21292        1      8       Sham  LTP476  -999      -999             NaN
# 21439        1      9        Neg  LTP476  -999      -999             NaN
# 22181        0      4        Neg  LTP477  -999      -999             NaN
# 22466        0      6       Sham  LTP477  -999      -999             NaN
# 23188        1      1        Pos  LTP477  -999      -999             NaN
# 25674        0      8        Neg  LTP478  -999      -999             NaN
# 26978        1      6        Neg  LTP478  -999      -999             NaN
# 27064        1      6        Neg  LTP478  -999      -999             NaN
# 27104        1      6        Neg  LTP478  -999      -999             NaN
# 27129        1      6        Neg  LTP478  -999      -999             NaN
# 27564        1      9       Sham  LTP478  -999      -999             NaN
# 28810        2      7       Sham  LTP478  -999      -999             NaN
# 29506        3      1        Pos  LTP478  -999      -999             NaN
# 29644        3      2       Sham  LTP478  -999      -999             NaN
# 29954        3      4        Pos  LTP478  -999      -999             NaN
# 30023        3      4        Pos  LTP478  -999      -999             NaN
# 30063        3      4        Pos  LTP478  -999      -999             NaN
# 30561        3      7        Neg  LTP478  -999      -999             NaN
# 32047        0      6        Neg  LTP479  -999      -999             NaN
# 32558        0      9       Sham  LTP479  -999      -999             NaN
# 33949        1      7        Neg  LTP479  -999      -999             NaN
# 34261        1      9        Neg  LTP479  -999      -999             NaN
# 34281        1      9        Neg  LTP479  -999      -999             NaN
# 35497        2      6        Neg  LTP479  -999      -999             NaN
# 35535        2      7        Neg  LTP479  -999      -999             NaN
# 35645        2      7        Neg  LTP479  -999      -999             NaN
# 35650        2      7        Neg  LTP479  -999      -999             NaN
# 35670        2      7        Neg  LTP479  -999      -999             NaN
# 35684        2      8       Sham  LTP479  -999      -999             NaN
# 35700        2      8       Sham  LTP479  -999      -999             NaN
# 35717        2      8       Sham  LTP479  -999      -999             NaN
# 35791        2      8       Sham  LTP479  -999      -999             NaN
# 35810        2      8       Sham  LTP479  -999      -999             NaN
# 35991        2      9        Neg  LTP479  -999      -999             NaN
# 36213        3      1       Sham  LTP479  -999      -999             NaN
# 36484        3      2        Neg  LTP479  -999      -999             NaN
# 36789        3      4        Pos  LTP479  -999      -999             NaN
# 36804        3      4        Pos  LTP479  -999      -999             NaN
# 37059        3      6        Neg  LTP479  -999      -999             NaN
# 37468        3      8       Sham  LTP479  -999      -999             NaN
# 37488        3      8       Sham  LTP479  -999      -999             NaN
# 37680        3      9        Neg  LTP479  -999      -999             NaN
# 40245        1      6        Pos  LTP481  -999      -999             NaN
# 40935        2      1        Pos  LTP481  -999      -999             NaN
# 41097        2      2        Neg  LTP481  -999      -999             NaN
# 41151        2      2        Neg  LTP481  -999      -999             NaN
# 41801        2      6        Neg  LTP481  -999      -999             NaN
# 41954        2      7       Sham  LTP481  -999      -999             NaN
# 41983        2      7       Sham  LTP481  -999      -999             NaN
# 41998        2      7       Sham  LTP481  -999      -999             NaN
# 45705        1      1       Sham  LTP484  -999      -999             NaN
# 47733        2      4        Neg  LTP484  -999      -999             NaN
# 49249        3      3        Neg  LTP484  -999      -999             NaN
# 49772        3      7       Sham  LTP484  -999      -999             NaN
# 53192        1      9        Pos  LTP486  -999      -999             NaN
# 53764        2      3       Sham  LTP486  -999      -999             NaN
# 53803        2      3       Sham  LTP486  -999      -999             NaN
# 58839        1      6        Pos  LTP488  -999      -999             NaN
# 60677        2      8       Sham  LTP488  -999      -999             NaN
# 60699        2      8       Sham  LTP488  -999      -999             NaN
# 61987        3      7        Pos  LTP488  -999      -999             NaN
# 63395        0      7        Pos  LTP493  -999      -999             NaN
# 63871        1      1        Pos  LTP493  -999      -999             NaN
# 65757        2      4       Sham  LTP493  -999      -999             NaN
# 66219        2      7        Pos  LTP493  -999      -999             NaN
# 68525        0      3        Pos  LTP494  -999      -999             NaN
# 72090        2      8        Neg  LTP494  -999      -999             NaN
# 72156        2      8        Neg  LTP494  -999      -999             NaN
# 72298        2      9        Neg  LTP494  -999      -999             NaN
# 72610        3      2        Pos  LTP494  -999      -999             NaN
# 72744        3      3        Neg  LTP494  -999      -999             NaN
# 72752        3      3        Neg  LTP494  -999      -999             NaN
# 72806        3      3        Neg  LTP494  -999      -999             NaN
# 73504        3      8       Sham  LTP494  -999      -999             NaN
# 73653        3      9       Sham  LTP494  -999      -999             NaN
# 73947        0      1        Neg  LTP495  -999      -999             NaN
# 76453        1      8        Pos  LTP495  -999      -999             NaN
# 77268        2      3        Neg  LTP495  -999      -999             NaN
# 80125        0      2       Sham  LTP496  -999      -999             NaN
# 82800        1      9       Sham  LTP496  -999      -999             NaN
# 82854        1      9       Sham  LTP496  -999      -999             NaN
# 83658        2      4        Pos  LTP496  -999      -999             NaN
# 84138        2      7        Neg  LTP496  -999      -999             NaN
# 85198        3      4       Sham  LTP496  -999      -999             NaN
# 86138        3      9        Pos  LTP496  -999      -999             NaN
# 86494        0      1       Sham  LTP497  -999      -999             NaN
# 86593        0      2        Neg  LTP497  -999      -999             NaN
# 86665        0      3        Pos  LTP497  -999      -999             NaN
# 88717        1      6        Pos  LTP497  -999      -999             NaN
# 93352        0      8        Neg  LTP498  -999      -999             NaN
# 93512        0      9       Sham  LTP498  -999      -999             NaN
# 93983        1      2        Pos  LTP498  -999      -999             NaN
# 94461        1      6        Pos  LTP498  -999      -999             NaN
# 94650        1      7        Neg  LTP498  -999      -999             NaN
# 94768        1      8       Sham  LTP498  -999      -999             NaN
# 94936        1      9       Sham  LTP498  -999      -999             NaN
# 94965        1      9       Sham  LTP498  -999      -999             NaN
# 96391        2      9        Pos  LTP498  -999      -999             NaN
# 96440        2      9        Pos  LTP498  -999      -999             NaN
# 96716        3      1       Sham  LTP498  -999      -999             NaN
# 96856        3      2       Sham  LTP498  -999      -999             NaN
# 97135        3      4        Neg  LTP498  -999      -999             NaN
# 97637        3      7        Neg  LTP498  -999      -999             NaN
# 97645        3      7        Neg  LTP498  -999      -999             NaN
# 97664        3      7        Neg  LTP498  -999      -999             NaN
# 97804        3      8        Pos  LTP498  -999      -999             NaN
#
#        time_class_result  eeg collection duration  classifier duration  \
# 858                  NaN                     <NA>                 <NA>
# 1776                 NaN                     <NA>                 <NA>
# 3260                 NaN                     <NA>                 <NA>
# 5307                 NaN                     <NA>                 <NA>
# 5310                 NaN                     <NA>                 <NA>
# 6340                 NaN                     <NA>                 <NA>
# 6392                 NaN                     <NA>                 <NA>
# 7718                 NaN                     <NA>                 <NA>
# 9254                 NaN                     <NA>                 <NA>
# 9699                 NaN                     <NA>                 <NA>
# 13107                NaN                     <NA>                 <NA>
# 13540                NaN                     <NA>                 <NA>
# 13653                NaN                     <NA>                 <NA>
# 14445                NaN                     <NA>                 <NA>
# 14640                NaN                     <NA>                 <NA>
# 15589                NaN                     <NA>                 <NA>
# 16023                NaN                     <NA>                 <NA>
# 16655                NaN                     <NA>                 <NA>
# 17985                NaN                     <NA>                 <NA>
# 18081                NaN                     <NA>                 <NA>
# 18943                NaN                     <NA>                 <NA>
# 19047                NaN                     <NA>                 <NA>
# 19895                NaN                     <NA>                 <NA>
# 20678                NaN                     <NA>                 <NA>
# 21292                NaN                     <NA>                 <NA>
# 21439                NaN                     <NA>                 <NA>
# 22181                NaN                     <NA>                 <NA>
# 22466                NaN                     <NA>                 <NA>
# 23188                NaN                     <NA>                 <NA>
# 25674                NaN                     <NA>                 <NA>
# 26978                NaN                     <NA>                 <NA>
# 27064                NaN                     <NA>                 <NA>
# 27104                NaN                     <NA>                 <NA>
# 27129                NaN                     <NA>                 <NA>
# 27564                NaN                     <NA>                 <NA>
# 28810                NaN                     <NA>                 <NA>
# 29506                NaN                     <NA>                 <NA>
# 29644                NaN                     <NA>                 <NA>
# 29954                NaN                     <NA>                 <NA>
# 30023                NaN                     <NA>                 <NA>
# 30063                NaN                     <NA>                 <NA>
# 30561                NaN                     <NA>                 <NA>
# 103453   11247589  1652211059523          X           FFR_REC_WORD
# 103454   11251124  1652211061249          X               FFR_STOP
# 103455   12001491  1652211427670          X  MUSIC_VIDEOS_REC_STOP
# 103456   12031281  1652211442217          X               SESS_END
#
#               item  itemno phase  session  trial trial_type subject  \
# 0             -999    -999     1        0      0     NoStim  LTP462
# 1             -999    -999     1        0      0     NoStim  LTP462
# 2        FISH_BOWL    -999     1        0      0     NoStim  LTP462
# 3             -999    -999     1        0      0     NoStim  LTP462
# 4        CHOCOLATE    -999     1        0      0     NoStim  LTP462
# ...            ...     ...   ...      ...    ...        ...     ...
# 103452  SWEATSHIRT     209     2        3   -999     NoStim  LTP500
# 103453      RIBBON     175     2        3   -999     NoStim  LTP500
# 103454        -999    -999     2        3      9       Sham  LTP500
# 103455        -999    -999     2        3      9       Sham  LTP500
# 103456        -999    -999     2        3      9       Sham  LTP500
#
#                  store  recalled  id  time_eeg_epoch  time_class_result  \
# 0                 -999      -999 NaN             NaN                NaN
# 1                 -999      -999 NaN             NaN                NaN
# 2            pet_store         1 NaN             NaN                NaN
# 3                 -999      -999 NaN             NaN                NaN
# 4                 cafe         1 NaN             NaN                NaN
# ...                ...       ...  ..             ...                ...
# 103452  clothing_store      -999 NaN             NaN                NaN
# 103453            -999      -999 NaN             NaN                NaN
# 103454            -999      -999 NaN             NaN                NaN
# 103455            -999      -999 NaN             NaN                NaN
# 103456            -999      -999 NaN             NaN                NaN
#
#         eeg collection duration  classifier duration normalized  result  \
# 0                           NaN                  NaN        NaN     NaN
# 1                           NaN                  NaN        NaN     NaN
# 2                           NaN                  NaN        NaN     NaN
# 3                           NaN                  NaN        NaN     NaN
# 4                           NaN                  NaN        NaN     NaN
# ...                         ...                  ...        ...     ...
# 103452                      NaN                  NaN        NaN     NaN
# 103453                      NaN                  NaN        NaN     NaN
# 103454                      NaN                  NaN        NaN     NaN
# 103455                      NaN                  NaN        NaN     NaN
# 103456                      NaN                  NaN        NaN     NaN
#
#         probability
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 103452          NaN
# 103453          NaN
# 103454          NaN
# 103455          NaN
# 103456          NaN
#
# [103457 rows x 21 columns]

# %%
for i, row in CL_evs.iterrows():
    if i+1 < len(CL_evs):
        CL_evs.at[i, 'next_type'] = CL_evs.at[i+1, 'type']
    if row["type"] in ['CLASSIFIER', 'TIMEOUT']:
        CL_evs.at[i, 'item'] = CL_evs.at[i+1, 'item']
        CL_evs.at[i, 'recalled'] = CL_evs.at[i+1, 'recalled']
        CL_evs.at[i, 'store'] = CL_evs.at[i+1, 'store']
    else:
        continue

# %%
pd.merge_asof(CL_evs.query("type in ['CLASSIFIER', 'TIMEOUT']"), CL_evs.query("type == 'WORD'"), by=['subject', 'session'])

# %%
CL_evs.query("session==3 and subject=='LTP481'").loc[42600:42600+25]
# Out:
#        eegoffset         mstime classifier             type             item  \
# 42600    1142728  1646424523635       Sham       CLASSIFIER          ASPIRIN
# 42601    1142730  1646424523636          X             WORD          ASPIRIN
# 42602    1171535  1646424537702          X  CLASSIFIER_WAIT             -999
# 42603    1178738  1646424541219       Sham       CLASSIFIER        MUSHROOMS
# 42603         1  4526.0    1.646425e+12       1.646425e+12
# 42604         1     NaN             NaN                NaN
# 42605      -999     NaN             NaN                NaN
# 42606      -999     NaN             NaN                NaN
# 42607         1  4674.0    1.646425e+12       1.646425e+12
# 42608         1     NaN             NaN                NaN
# 42609      -999     NaN             NaN                NaN
# 42610         1  4798.0    1.646425e+12       1.646425e+12
# 42611         1     NaN             NaN                NaN
# 42612      -999     NaN             NaN                NaN
# 42613      -999     NaN             NaN                NaN
# 42614         1  4966.0    1.646425e+12       1.646425e+12
# 42615         1     NaN             NaN                NaN
# 42616      -999     NaN             NaN                NaN
# 42617      -999     NaN             NaN                NaN
# 42618         1  5124.0    1.646425e+12       1.646425e+12
# 42619         1     NaN             NaN                NaN
# 42620      -999     NaN             NaN                NaN
# 42621      -999     NaN             NaN                NaN
# 42622         1  5275.0    1.646425e+12       1.646425e+12
# 42623         1     NaN             NaN                NaN
# 42624      -999     NaN             NaN                NaN
# 42625      -999     NaN             NaN                NaN
#
#        eeg collection duration  classifier duration normalized  result  \
# 42600                      2.0             0.178988       True     1.0
# 42601                      NaN                  NaN        NaN     NaN
# 42602                      NaN                  NaN        NaN     NaN
# 42603                      2.0             0.175715       True     0.0
# 42604                      NaN                  NaN        NaN     NaN
# 42605                      NaN                  NaN        NaN     NaN
# 42606                      NaN                  NaN        NaN     NaN
# 42607                      2.0             0.188313       True     0.0
# 42608                      NaN                  NaN        NaN     NaN
# 42609                      NaN                  NaN        NaN     NaN
# 42610                      2.0             0.177113       True     0.0
# 42611                      NaN                  NaN        NaN     NaN
# 42612                      NaN                  NaN        NaN     NaN
# 42613                      NaN                  NaN        NaN     NaN
# 42614                      2.0             0.193326       True     1.0
# 42615                      NaN                  NaN        NaN     NaN
# 42616                      NaN                  NaN        NaN     NaN
# 42617                      NaN                  NaN        NaN     NaN
# 42618                      2.0             0.197441       True     0.0
# 42619                      NaN                  NaN        NaN     NaN
# 42620                      NaN                  NaN        NaN     NaN
# 42621                      NaN                  NaN        NaN     NaN
# 42622                      2.0             0.173903       True     0.0
# 42623                      NaN                  NaN        NaN     NaN
# 42624                      NaN                  NaN        NaN     NaN
# 42625                      NaN                  NaN        NaN     NaN
#
#        probability
# 42600     0.557667
# 42601          NaN
# 42602          NaN
# 42603     0.319504
# 42604          NaN
# 42605          NaN
# 42606          NaN
# 42607     0.322328
# 42608          NaN
# 42609          NaN
# 42610     0.426473
# 42611          NaN
# 42612          NaN
# 42613          NaN
# 42614     0.615575
# 42615          NaN
# 42616          NaN
# 42617          NaN
# 42618     0.437811
# 42619          NaN
# 42620          NaN
# 42621          NaN
# 42622     0.423013
# 42623          NaN
# 42624          NaN
# 42625          NaN

# %% [markdown]
# ### Classifier wait times

# %%
wait_df = []
gb = CL_evs.groupby(["subject", 'session', 'trial'])
for (sub, sess, tri), df in gb:
    waits = df.query("type in ['CLASSIFIER', 'CLASSIFIER_WAIT', 'TIMEOUT']")[['mstime']].diff()[1::2]
    waits = waits.rename(columns={"mstime":"wait_time"})
    waits = pd.merge(df, waits, left_index=True, right_index=True, how='left')
#     waits['subject'] = sub
#     waits['session'] = sess
#     waits['trial'] = tri
#     waits['trial_type'] = df[1::2]['trial_type']
#     waits['type'] = df[1::2]['type']
#     waits['probability'] = df[1::2]['probability']
#     waits['classifier duration'] = df[1::2]['classifier duration']
    wait_df.append(waits)
wait_df = pd.concat(wait_df)

# %%
wait_df.query("type=='TIMEOUT'")
# Out:
#         eegoffset         mstime classifier     type       item  itemno phase  \
# 125     1388189.0  1634305103436        Pos  TIMEOUT      APRON    -999     1
# 200     1890155.0  1634305348554        Pos  TIMEOUT  LOLLIPOPS    -999     1
# 205     1911860.0  1634305359153        Pos  TIMEOUT       GLUE    -999     1
# 210     1936707.0  1634305371286        Pos  TIMEOUT      PEARS    -999     1
# 220     1981008.0  1634305392919        Pos  TIMEOUT      APRON    -999     1
# ...           ...            ...        ...      ...        ...     ...   ...
# 103110  9720068.0  1652210313600        Neg  TIMEOUT  HAIR_CLIP    -999     2
# 103120  9760647.0  1652210333416        Neg  TIMEOUT       BELL    -999     2
# 103125  9780376.0  1652210343050        Neg  TIMEOUT     SCREWS    -999     2
# 103130  9802253.0  1652210353733        Neg  TIMEOUT  FISH_BOWL    -999     2
# 103135  9821230.0  1652210363000        Neg  TIMEOUT      SCALE    -999     2
#
#         session  trial trial_type subject              experiment  \
# 125           0      1        Pos  LTP462  NiclsCourierClosedLoop
# 200           0      1        Pos  LTP462  NiclsCourierClosedLoop
# 205           0      1        Pos  LTP462  NiclsCourierClosedLoop
# 210           0      1        Pos  LTP462  NiclsCourierClosedLoop
# 220           0      1        Pos  LTP462  NiclsCourierClosedLoop
# ...         ...    ...        ...     ...                     ...
# 103110        3      8        Neg  LTP500  NiclsCourierClosedLoop
# 103120        3      8        Neg  LTP500  NiclsCourierClosedLoop
# 103125        3      8        Neg  LTP500  NiclsCourierClosedLoop
# 103130        3      8        Neg  LTP500  NiclsCourierClosedLoop
# 103135        3      8        Neg  LTP500  NiclsCourierClosedLoop
#
#                                                   eegfile           store  \
# 125     /protocols/ltp/subjects/LTP462/experiments/Nic...          bakery
# 200     /protocols/ltp/subjects/LTP462/experiments/Nic...         dentist
# 205     /protocols/ltp/subjects/LTP462/experiments/Nic...      craft_shop
# 210     /protocols/ltp/subjects/LTP462/experiments/Nic...   grocery_store
# 220     /protocols/ltp/subjects/LTP462/experiments/Nic...          bakery
# ...                                                   ...             ...
# 103110  /protocols/ltp/subjects/LTP500/experiments/Nic...   jewelry_store
# 103120  /protocols/ltp/subjects/LTP500/experiments/Nic...       bike_shop
# 103125  /protocols/ltp/subjects/LTP500/experiments/Nic...  hardware_store
# 103130  /protocols/ltp/subjects/LTP500/experiments/Nic...       pet_store
# 103135  /protocols/ltp/subjects/LTP500/experiments/Nic...             gym
#
#         recalled  id  time_eeg_epoch  time_class_result  \
# 125            1 NaN             NaN                NaN
# 200         -999 NaN             NaN                NaN
# 205         -999 NaN             NaN                NaN
# 210         -999 NaN             NaN                NaN
# 220         -999 NaN             NaN                NaN
# ...          ...  ..             ...                ...
# 103110      -999 NaN             NaN                NaN
# 103120      -999 NaN             NaN                NaN
# 103125      -999 NaN             NaN                NaN
# 103130      -999 NaN             NaN                NaN
# 103135      -999 NaN             NaN                NaN
#
#         eeg collection duration  classifier duration normalized  result  \
# 125                         NaN                  NaN        NaN     NaN
# 200                         NaN                  NaN        NaN     NaN
# 205                         NaN                  NaN        NaN     NaN
# 210                         NaN                  NaN        NaN     NaN
# 220                         NaN                  NaN        NaN     NaN
# ...                         ...                  ...        ...     ...
# 103110                      NaN                  NaN        NaN     NaN
# 103120                      NaN                  NaN        NaN     NaN
# 103125                      NaN                  NaN        NaN     NaN
# 103130                      NaN                  NaN        NaN     NaN
# 103135                      NaN                  NaN        NaN     NaN
#
#         probability     next_type        prev_type  orig_eegoffset  wait_time
# 125             NaN          WORD  CLASSIFIER_WAIT             NaN     5000.0
# 200             NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5001.0
# 205             NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5000.0
# 210             NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5000.0
# 220             NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     4999.0
# ...             ...           ...              ...             ...        ...
# 103110          NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     4999.0
# 103120          NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5000.0
# 103125          NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5001.0
# 103130          NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5000.0
# 103135          NaN  CUED_REC_CUE  CLASSIFIER_WAIT             NaN     5000.0
#
# [2940 rows x 27 columns]

# %%
wait_df['wait_time'].argmax()
# Out:
# 15897

# %%
CL_evs.query("type in ['CLASSIFIER', 'TIMEOUT']")['classifier duration']
# Out:
# 93        0.171522
# 97        0.171078
# 101       0.172517
# 105       0.170400
# 108       0.168759
#             ...
# 103304    0.203262
# 103309    0.180348
# 103314    0.167918
# 103318    0.170764
# 103323    0.212920
# Name: classifier duration, Length: 16170, dtype: float64

# %%
CL_evs
# Out:
#           eegoffset         mstime classifier                   type  \
# 0         11484.000  1634304431169          X         store mappings
# 1        116586.000  1634304482492          X            TRIAL_START
# 2        125552.000  1634304486870          X                   WORD
# 3        153470.000  1634304500503          X             POINTER_ON
# 4        159546.000  1634304503470          X                   WORD
# ...             ...            ...        ...                    ...
# 103452 11247413.000  1652211059437          X           FFR_REC_WORD
# 103453 11247589.000  1652211059523          X           FFR_REC_WORD
# 103454 11251124.000  1652211061249          X               FFR_STOP
# 103455 12001491.000  1652211427670          X  MUSIC_VIDEOS_REC_STOP
# 103456 12031281.000  1652211442217          X               SESS_END
#
#               item  itemno  phase  session  trial trial_type subject  \
# 0             -999    -999      1        0      0     NoStim  LTP462
# 1             -999    -999      1        0      0     NoStim  LTP462
# 2        FISH_BOWL    -999      1        0      0     NoStim  LTP462
# 3             -999    -999      1        0      0     NoStim  LTP462
# 4        CHOCOLATE    -999      1        0      0     NoStim  LTP462
# ...            ...     ...    ...      ...    ...        ...     ...
# 103452  SWEATSHIRT     209      2        3   -999     NoStim  LTP500
# 103453      RIBBON     175      2        3   -999     NoStim  LTP500
# 103454        -999    -999      2        3      9       Sham  LTP500
# 103455        -999    -999      2        3      9       Sham  LTP500
# 103456        -999    -999      2        3      9       Sham  LTP500
#
#                     experiment  \
# 0       NiclsCourierClosedLoop
# 1       NiclsCourierClosedLoop
# 2       NiclsCourierClosedLoop
# 3       NiclsCourierClosedLoop
# 4       NiclsCourierClosedLoop
# ...                        ...
# 103452  NiclsCourierClosedLoop
# 103453  NiclsCourierClosedLoop
# 103454  NiclsCourierClosedLoop
# 103455  NiclsCourierClosedLoop
# 103456  NiclsCourierClosedLoop
#
#                                                   eegfile           store  \
# 0       /protocols/ltp/subjects/LTP462/experiments/Nic...            -999
# 1       /protocols/ltp/subjects/LTP462/experiments/Nic...            -999
# 2       /protocols/ltp/subjects/LTP462/experiments/Nic...       pet_store
# 3       /protocols/ltp/subjects/LTP462/experiments/Nic...            -999
# 4       /protocols/ltp/subjects/LTP462/experiments/Nic...            cafe
# ...                                                   ...             ...
# 103452  /protocols/ltp/subjects/LTP500/experiments/Nic...  clothing_store
# 103453  /protocols/ltp/subjects/LTP500/experiments/Nic...            -999
# 103454  /protocols/ltp/subjects/LTP500/experiments/Nic...            -999
# 103455  /protocols/ltp/subjects/LTP500/experiments/Nic...            -999
# 103456  /protocols/ltp/subjects/LTP500/experiments/Nic...            -999
#
#         recalled  id  time_eeg_epoch  time_class_result  \
# 0           -999 NaN             NaN                NaN
# 1           -999 NaN             NaN                NaN
# 2              1 NaN             NaN                NaN
# 3           -999 NaN             NaN                NaN
# 4              1 NaN             NaN                NaN
# ...          ...  ..             ...                ...
# 103452      -999 NaN             NaN                NaN
# 103453      -999 NaN             NaN                NaN
# 103454      -999 NaN             NaN                NaN
# 103455      -999 NaN             NaN                NaN
# 103456      -999 NaN             NaN                NaN
#
#         eeg collection duration  classifier duration normalized  result  \
# 0                           NaN                  NaN        NaN     NaN
# 1                           NaN                  NaN        NaN     NaN
# 2                           NaN                  NaN        NaN     NaN
# 3                           NaN                  NaN        NaN     NaN
# 4                           NaN                  NaN        NaN     NaN
# ...                         ...                  ...        ...     ...
# 103452                      NaN                  NaN        NaN     NaN
# 103453                      NaN                  NaN        NaN     NaN
# 103454                      NaN                  NaN        NaN     NaN
# 103455                      NaN                  NaN        NaN     NaN
# 103456                      NaN                  NaN        NaN     NaN
#
#         probability              next_type  orig_eegoffset
# 0               NaN            TRIAL_START             NaN
# 1               NaN                   WORD             NaN
# 2               NaN             POINTER_ON             NaN
# 3               NaN                   WORD             NaN
# 4               NaN             POINTER_ON             NaN
# ...             ...                    ...             ...
# 103452          NaN           FFR_REC_WORD             NaN
# 103453          NaN               FFR_STOP             NaN
# 103454          NaN  MUSIC_VIDEOS_REC_STOP             NaN
# 103455          NaN               SESS_END             NaN
# 103456          NaN                    NaN             NaN
#
# [103457 rows x 25 columns]

# %%
plt.figure(figsize=(8,4))
sns.histplot(wait_df,
             x='wait_time', stat='probability', binwidth=200, hue='trial_type')
plt.xlim(-100, 5300)
plt.xlabel('Time Waiting for Classifier')
plt.savefig("classifier_wait_times.pdf", dpi=200)

# %% [markdown]
# ## Apparent buggy behavior: not timing out

# %%
wait_df[wait_df['wait_time']>6000]
# Out:
#         wait_time subject  session  trial trial_type        type  probability  \
# 101456     7549.0  LTP500        2      2        Pos  CLASSIFIER     0.971811
# 101511    13733.0  LTP500        2      2        Pos  CLASSIFIER     0.765077
# 101567     8850.0  LTP500        2      3       Sham  CLASSIFIER     0.999990
# 101628     9167.0  LTP500        2      3       Sham  CLASSIFIER     0.053994
#
#         classifier duration
# 101456             0.191906
# 101511             0.183047
# 101567             0.172272
# 101628             0.175169

# %%
pd.options.display.max_rows = 300
CL_evs.query("trial_type=='Neg'")[200:400]
# Out:
#       eegoffset         mstime classifier             type  \
# 854   8539913.0  1634308595837        Neg       CLASSIFIER
# 855   8540119.0  1634308595838          X     CUED_REC_CUE
# 856   8551960.0  1634308601620          X    CUED_REC_STOP
# 857   8556090.0  1634308603637          X  CLASSIFIER_WAIT
# 858   8555901.0  1634308603653        Neg       CLASSIFIER
# 859   8556123.0  1634308603653          X     CUED_REC_CUE
# 860   8566188.0  1634308608568          X    CUED_REC_WORD
# 861   8568410.0  1634308609653          X    CUED_REC_STOP
# 862   8572539.0  1634308611669          X  CLASSIFIER_WAIT
# 863   8572365.0  1634308611686        Neg       CLASSIFIER
# 864   8572578.0  1634308611688          X     CUED_REC_CUE
# 865   8582278.0  1634308616425          X    CUED_REC_WORD
# 866   8584861.0  1634308617686          X    CUED_REC_STOP
# 867   8588959.0  1634308619687          X  CLASSIFIER_WAIT
# 868   8588805.0  1634308619703        Neg       CLASSIFIER
# 869   8588993.0  1634308619704          X     CUED_REC_CUE
# 870   8595198.0  1634308622734          X    CUED_REC_WORD
# 871   8597320.0  1634308623770          X    CUED_REC_STOP
# 872   8601450.0  1634308625787          X  CLASSIFIER_WAIT
# 873   8601271.0  1634308625803        Neg       CLASSIFIER
# 874   8601485.0  1634308625804          X     CUED_REC_CUE
# 875   8611911.0  1634308630895          X    CUED_REC_WORD
# 876   8613805.0  1634308631820          X    CUED_REC_STOP
# 877   8617936.0  1634308633837          X  CLASSIFIER_WAIT
# 878   8617778.0  1634308633853        Neg       CLASSIFIER
# 879   8617971.0  1634308633854          X     CUED_REC_CUE
# 880   8624851.0  1634308637214          X    CUED_REC_WORD
# 881   8627151.0  1634308638337          X    CUED_REC_STOP
# 882   8631280.0  1634308640353          X  CLASSIFIER_WAIT
# 883   8631120.0  1634308640370        Neg       CLASSIFIER
# 884   8631316.0  1634308640371          X     CUED_REC_CUE
# 885   8634335.0  1634308641845          X    CUED_REC_WORD
# 886   8636739.0  1634308643019          X    CUED_REC_STOP
# 887   8640835.0  1634308645019          X  CLASSIFIER_WAIT
# 888   8640678.0  1634308645037        Neg       CLASSIFIER
# 889   8640872.0  1634308645037          X     CUED_REC_CUE
# 890   8650972.0  1634308649969          X    CUED_REC_STOP
# 891   8655104.0  1634308651987          X  CLASSIFIER_WAIT
# 892   8654936.0  1634308652003        Neg       CLASSIFIER
# 893   8655139.0  1634308652004          X     CUED_REC_CUE
# 894   8667424.0  1634308658003          X    CUED_REC_STOP
# 895   8671555.0  1634308660020          X  CLASSIFIER_WAIT
# 896   8671409.0  1634308660036        Neg       CLASSIFIER
# 897   8671589.0  1634308660037          X     CUED_REC_CUE
# 898   8675792.0  1634308662089          X    CUED_REC_WORD
# 899   8678005.0  1634308663170          X    CUED_REC_STOP
# 900   8682101.0  1634308665170          X  CLASSIFIER_WAIT
# 901   8681950.0  1634308665186        Neg       CLASSIFIER
# 902   8682136.0  1634308665187          X     CUED_REC_CUE
# 903   8693796.0  1634308670881          X    CUED_REC_WORD
# 904   8694423.0  1634308671187          X    CUED_REC_STOP
# 905   8698519.0  1634308673187          X  CLASSIFIER_WAIT
# 906   8698364.0  1634308673204        Neg       CLASSIFIER
# 907   8698556.0  1634308673205          X     CUED_REC_CUE
# 908   8709186.0  1634308678396          X    CUED_REC_WORD
# 909   8710873.0  1634308679220          X    CUED_REC_STOP
# 910   8714969.0  1634308681220          X  CLASSIFIER_WAIT
# 911   8714832.0  1634308681237        Neg       CLASSIFIER
# 912   8715006.0  1634308681238          X     CUED_REC_CUE
# 913   8721010.0  1634308684170          X    CUED_REC_STOP
# 914   8725174.0  1634308686203          X  CLASSIFIER_WAIT
# 915   8725012.0  1634308686220        Neg       CLASSIFIER
# 916   8725210.0  1634308686221          X     CUED_REC_CUE
# 917   8737528.0  1634308692236          X    CUED_REC_STOP
# 918   8741624.0  1634308694236          X  CLASSIFIER_WAIT
# 919   8741892.0  1634308694453        Neg       CLASSIFIER
# 920   8742068.0  1634308694453          X     CUED_REC_CUE
# 921   8754358.0  1634308700454          X    CUED_REC_STOP
# 922   8764357.0  1634308705337          X      TRIAL_START
# 923   8788966.0  1634308717354          X       POINTER_ON
# 924   8804153.0  1634308724770          X  CLASSIFIER_WAIT
# 925   8804932.0  1634308725237        Neg       CLASSIFIER
# 926   8805110.0  1634308725237          X             WORD
# 927   8833083.0  1634308738897          X       POINTER_ON
# 928   8862175.0  1634308753103          X  CLASSIFIER_WAIT
# 929   8862014.0  1634308753120        Neg       CLASSIFIER
# 930   8862210.0  1634308753120          X             WORD
# 931   8873915.0  1634308758836          X  CLASSIFIER_WAIT
# 932   8873773.0  1634308758853        Neg       CLASSIFIER
# 933   8873950.0  1634308758853          X             WORD
# 934   8901836.0  1634308772470          X       POINTER_ON
# 935   8956651.0  1634308799237          X  CLASSIFIER_WAIT
# 936   8956505.0  1634308799253        Neg       CLASSIFIER
# 937   8956684.0  1634308799253          X             WORD
# 938   8985456.0  1634308813303          X  CLASSIFIER_WAIT
# 939   8985308.0  1634308813320        Neg       CLASSIFIER
# 940   8985491.0  1634308813320          X             WORD
# 941   9013409.0  1634308826953          X       POINTER_ON
# 942   9019110.0  1634308829737          X  CLASSIFIER_WAIT
# 943   9018960.0  1634308829753        Neg       CLASSIFIER
# 944   9019143.0  1634308829753          X             WORD
# 945   9047029.0  1634308843370          X       POINTER_ON
# 946   9066723.0  1634308852987          X  CLASSIFIER_WAIT
# 947   9066771.0  1634308853103        Neg       CLASSIFIER
# 948   9066963.0  1634308853104          X             WORD
# 949   9094844.0  1634308866719          X       POINTER_ON
# 950   9128566.0  1634308883186          X  CLASSIFIER_WAIT
# 951   9129279.0  1634308883620        Neg       CLASSIFIER
# 952   9129455.0  1634308883620          X             WORD
# 953   9151127.0  1634308894203          X  CLASSIFIER_WAIT
# 954   9150981.0  1634308894220        Neg       CLASSIFIER
# 955   9151162.0  1634308894220          X             WORD
# 956   9179046.0  1634308907836          X       POINTER_ON
# 957   9188808.0  1634308912603          X  CLASSIFIER_WAIT
# 958   9188653.0  1634308912620        Neg       CLASSIFIER
# 959   9188843.0  1634308912620          X             WORD
# 960   9208604.0  1634308922270          X  CLASSIFIER_WAIT
# 961   9208458.0  1634308922287        Neg       CLASSIFIER
# 962   9208639.0  1634308922287          X             WORD
# 963   9236558.0  1634308935920          X       POINTER_ON
# 964   9241915.0  1634308938536          X  CLASSIFIER_WAIT
# 965   9241741.0  1634308938553        Neg       CLASSIFIER
# 966   9241952.0  1634308938554          X             WORD
# 967   9269870.0  1634308952187          X       POINTER_ON
# 968   9280517.0  1634308957386          X  CLASSIFIER_WAIT
# 969   9280251.0  1634308957403        Neg       CLASSIFIER
# 970   9280552.0  1634308957403          X             WORD
# 971   9308437.0  1634308971020          X       POINTER_ON
# 972   9323114.0  1634308978187          X  CLASSIFIER_WAIT
# 973   9322963.0  1634308978203        Neg       CLASSIFIER
# 974   9323147.0  1634308978203          X             WORD
# 975   9351068.0  1634308991837          X       POINTER_ON
# 976   9370897.0  1634309001520          X  CLASSIFIER_WAIT
# 977   9370756.0  1634309001537        Neg       CLASSIFIER
# 978   9370932.0  1634309001537          X             WORD
# 979   9428304.0  1634309029553          X        TRIAL_END
# 980   9450833.0  1634309040554          X        REC_START
# 981   9452430.0  1634309041334          X         REC_WORD
# 982   9455379.0  1634309042774          X         REC_WORD
# 983   9458758.0  1634309044424          X         REC_WORD
# 984   9461605.0  1634309045814          X         REC_WORD
# 985   9474957.0  1634309052334          X         REC_WORD
# 986   9495271.0  1634309062254          X         REC_WORD
# 987   9499777.0  1634309064454          X         EFR_MARK
# 988   9499777.0  1634309064454          X         EFR_MARK
# 989   9520040.0  1634309074349          X         REC_WORD
# 990   9635172.0  1634309130570          X         REC_STOP
# 991   9652577.0  1634309139069          X  CLASSIFIER_WAIT
# 992   9652393.0  1634309139086        Neg       CLASSIFIER
# 993   9652614.0  1634309139087          X     CUED_REC_CUE
# 994   9661403.0  1634309143379          X    CUED_REC_WORD
# 995   9664901.0  1634309145087          X    CUED_REC_STOP
# 996   9669030.0  1634309147103          X  CLASSIFIER_WAIT
# 997   9668884.0  1634309147120        Neg       CLASSIFIER
# 998   9669067.0  1634309147121          X     CUED_REC_CUE
# 999   9674866.0  1634309149953          X    CUED_REC_STOP
# 1000  9678997.0  1634309151970          X  CLASSIFIER_WAIT
# 1001  9678856.0  1634309151986        Neg       CLASSIFIER
# 1002  9679031.0  1634309151987          X     CUED_REC_CUE
# 965              PEONIES    -999     2        0      7        Neg  LTP462
# 966              PEONIES    -999     2        0      7        Neg  LTP462
# 967                 -999    -999     2        0      7        Neg  LTP462
# 968                 -999    -999     2        0      7        Neg  LTP462
# 969               Q-TIPS    -999     2        0      7        Neg  LTP462
# 970               Q-TIPS    -999     2        0      7        Neg  LTP462
# 971                 -999    -999     2        0      7        Neg  LTP462
# 972                 -999    -999     2        0      7        Neg  LTP462
# 973             SCISSORS    -999     2        0      7        Neg  LTP462
# 974             SCISSORS    -999     2        0      7        Neg  LTP462
# 975                 -999    -999     2        0      7        Neg  LTP462
# 976                 -999    -999     2        0      7        Neg  LTP462
# 977          SWEET-N-LOW    -999     2        0      7        Neg  LTP462
# 978          SWEET-N-LOW    -999     2        0      7        Neg  LTP462
# 979                 -999    -999     2        0      7        Neg  LTP462
# 980                 -999    -999     2        0      7        Neg  LTP462
# 981                  CDS      -1     2        0      7        Neg  LTP462
# 982               JACKET     114     2        0      7        Neg  LTP462
# 983             CHEW_TOY      45     2        0      7        Neg  LTP462
# 984              OREGANO     149     2        0      7        Neg  LTP462
# 985   CONSTRUCTION_PAPER      55     2        0      7        Neg  LTP462
# 986                PAINT     150     2        0      7        Neg  LTP462
# 987                 -999    -999     2        0      7        Neg  LTP462
# 988                 -999    -999     2        0      7        Neg  LTP462
# 989              PEONIES     157     2        0      7        Neg  LTP462
# 990                 -999    -999     2        0      7        Neg  LTP462
# 991                 -999    -999     2        0      7        Neg  LTP462
# 992             SCISSORS    -999     2        0      7        Neg  LTP462
# 993             SCISSORS    -999     2        0      7        Neg  LTP462
# 994             SCISSORS     186     2        0      7        Neg  LTP462
# 995                 -999    -999     2        0      7        Neg  LTP462
# 996                 -999    -999     2        0      7        Neg  LTP462
# 997              PENDANT    -999     2        0      7        Neg  LTP462
# 998              PENDANT    -999     2        0      7        Neg  LTP462
# 999                 -999    -999     2        0      7        Neg  LTP462
# 1000                -999    -999     2        0      7        Neg  LTP462
# 1001               FLOUR    -999     2        0      7        Neg  LTP462
# 1002               FLOUR    -999     2        0      7        Neg  LTP462
# 1003                -999    -999     2        0      7        Neg  LTP462
# 1004                -999    -999     2        0      7        Neg  LTP462
# 1005              Q-TIPS    -999     2        0      7        Neg  LTP462
# 1006              Q-TIPS    -999     2        0      7        Neg  LTP462
# 1007                -999    -999     2        0      7        Neg  LTP462
# 1008                -999    -999     2        0      7        Neg  LTP462
# 1009     KARAOKE_MACHINE    -999     2        0      7        Neg  LTP462
# 1010     KARAOKE_MACHINE    -999     2        0      7        Neg  LTP462
# 1011                -999    -999     2        0      7        Neg  LTP462
# 1012                -999    -999     2        0      7        Neg  LTP462
# 1013           ASPARAGUS    -999     2        0      7        Neg  LTP462
# 1014           ASPARAGUS    -999     2        0      7        Neg  LTP462
# 1015                -999    -999     2        0      7        Neg  LTP462
# 1016                -999    -999     2        0      7        Neg  LTP462
# 1017  CONSTRUCTION_PAPER    -999     2        0      7        Neg  LTP462
# 1018  CONSTRUCTION_PAPER    -999     2        0      7        Neg  LTP462
# 1019                -999    -999     2        0      7        Neg  LTP462
# 1020                -999    -999     2        0      7        Neg  LTP462
# 1021              JACKET    -999     2        0      7        Neg  LTP462
# 1022              JACKET    -999     2        0      7        Neg  LTP462
# 1023                -999    -999     2        0      7        Neg  LTP462
# 1024                -999    -999     2        0      7        Neg  LTP462
# 1025         SWEET-N-LOW    -999     2        0      7        Neg  LTP462
# 1026         SWEET-N-LOW    -999     2        0      7        Neg  LTP462
# 1027         SWEET-N-LOW     210     2        0      7        Neg  LTP462
# 1028                -999    -999     2        0      7        Neg  LTP462
# 1029                -999    -999     2        0      7        Neg  LTP462
# 1030        BASEBALL_BAT    -999     2        0      7        Neg  LTP462
# 1031        BASEBALL_BAT    -999     2        0      7        Neg  LTP462
# 1032                -999    -999     2        0      7        Neg  LTP462
# 1033                -999    -999     2        0      7        Neg  LTP462
# 1034            CHEW_TOY    -999     2        0      7        Neg  LTP462
# 1035            CHEW_TOY    -999     2        0      7        Neg  LTP462
# 1036            CHEW_TOY      45     2        0      7        Neg  LTP462
# 1037                -999    -999     2        0      7        Neg  LTP462
# 1038                -999    -999     2        0      7        Neg  LTP462
# 1039             OREGANO    -999     2        0      7        Neg  LTP462
# 1040             OREGANO    -999     2        0      7        Neg  LTP462
# 1041             OREGANO     149     2        0      7        Neg  LTP462
# 1042                -999    -999     2        0      7        Neg  LTP462
# 1043                -999    -999     2        0      7        Neg  LTP462
# 1044                 CDS    -999     2        0      7        Neg  LTP462
# 1045                 CDS    -999     2        0      7        Neg  LTP462
# 1046                -999    -999     2        0      7        Neg  LTP462
# 1047                -999    -999     2        0      7        Neg  LTP462
# 1048     TRAINING_WHEELS    -999     2        0      7        Neg  LTP462
# 1049     TRAINING_WHEELS    -999     2        0      7        Neg  LTP462
# 1050                -999    -999     2        0      7        Neg  LTP462
# 1051                -999    -999     2        0      7        Neg  LTP462
# 1052             PEONIES    -999     2        0      7        Neg  LTP462
# 1053             PEONIES    -999     2        0      7        Neg  LTP462
#
#                store  recalled       id  time_eeg_epoch  time_class_result  \
# 854        toy_store      -999  33296.0    1.634309e+12       1.634309e+12
# 855        toy_store      -999      NaN             NaN                NaN
# 856             -999      -999      NaN             NaN                NaN
# 857             -999      -999      NaN             NaN                NaN
# 858              gym      -999  33358.0    1.634309e+12       1.634309e+12
# 859              gym      -999      NaN             NaN                NaN
# 860             -999      -999      NaN             NaN                NaN
# 861             -999      -999      NaN             NaN                NaN
# 862             -999      -999      NaN             NaN                NaN
# 863       craft_shop      -999  33423.0    1.634309e+12       1.634309e+12
# 864       craft_shop      -999      NaN             NaN                NaN
# 865             -999      -999      NaN             NaN                NaN
# 866             -999      -999      NaN             NaN                NaN
# 867             -999      -999      NaN             NaN                NaN
# 868           bakery      -999  33487.0    1.634309e+12       1.634309e+12
# 869           bakery      -999      NaN             NaN                NaN
# 870             -999      -999      NaN             NaN                NaN
# 871             -999      -999      NaN             NaN                NaN
# 872             -999      -999      NaN             NaN                NaN
# 873    grocery_store      -999  33536.0    1.634309e+12       1.634309e+12
# 874    grocery_store      -999      NaN             NaN                NaN
# 875             -999      -999      NaN             NaN                NaN
# 876             -999      -999      NaN             NaN                NaN
# 877             -999      -999      NaN             NaN                NaN
# 878          florist      -999  33600.0    1.634309e+12       1.634309e+12
# 879          florist      -999      NaN             NaN                NaN
# 880             -999      -999      NaN             NaN                NaN
# 881             -999      -999      NaN             NaN                NaN
# 882             -999      -999      NaN             NaN                NaN
# 883        bike_shop      -999  33652.0    1.634309e+12       1.634309e+12
# 884        bike_shop      -999      NaN             NaN                NaN
# 885             -999      -999      NaN             NaN                NaN
# 886             -999      -999      NaN             NaN                NaN
# 887             -999      -999      NaN             NaN                NaN
# 888         pharmacy      -999  33690.0    1.634309e+12       1.634309e+12
# 889         pharmacy      -999      NaN             NaN                NaN
# 890             -999      -999      NaN             NaN                NaN
# 891             -999      -999      NaN             NaN                NaN
# 892   clothing_store      -999  33745.0    1.634309e+12       1.634309e+12
# 893   clothing_store      -999      NaN             NaN                NaN
# 894             -999      -999      NaN             NaN                NaN
# 895             -999      -999      NaN             NaN                NaN
# 896    jewelry_store      -999  33810.0    1.634309e+12       1.634309e+12
# 897    jewelry_store      -999      NaN             NaN                NaN
# 898             -999      -999      NaN             NaN                NaN
# 899             -999      -999      NaN             NaN                NaN
# 900             -999      -999      NaN             NaN                NaN
# 901      music_store      -999  33851.0    1.634309e+12       1.634309e+12
# 902      music_store      -999      NaN             NaN                NaN
# 903             -999      -999      NaN             NaN                NaN
# 904             -999      -999      NaN             NaN                NaN
# 905             -999      -999      NaN             NaN                NaN
# 906        pet_store      -999  33915.0    1.634309e+12       1.634309e+12
# 907        pet_store      -999      NaN             NaN                NaN
# 908             -999      -999      NaN             NaN                NaN
# 909             -999      -999      NaN             NaN                NaN
# 910             -999      -999      NaN             NaN                NaN
# 911         pizzeria      -999  33979.0    1.634309e+12       1.634309e+12
# 912         pizzeria      -999      NaN             NaN                NaN
# 913             -999      -999      NaN             NaN                NaN
# 914             -999      -999      NaN             NaN                NaN
# 915          dentist      -999  34019.0    1.634309e+12       1.634309e+12
# 916          dentist      -999      NaN             NaN                NaN
# 917             -999      -999      NaN             NaN                NaN
# 918             -999      -999      NaN             NaN                NaN
# 919             cafe      -999  34085.0    1.634309e+12       1.634309e+12
# 920             cafe      -999      NaN             NaN                NaN
# 921             -999      -999      NaN             NaN                NaN
# 922             -999      -999      NaN             NaN                NaN
# 923             -999      -999      NaN             NaN                NaN
# 924             -999      -999      NaN             NaN                NaN
# 925        toy_store         0  34331.0    1.634309e+12       1.634309e+12
# 926        toy_store         0      NaN             NaN                NaN
# 927             -999      -999      NaN             NaN                NaN
# 928             -999      -999      NaN             NaN                NaN
# 929    grocery_store         0  34554.0    1.634309e+12       1.634309e+12
# 930    grocery_store         0      NaN             NaN                NaN
# 931             -999      -999      NaN             NaN                NaN
# 932              gym         0  34600.0    1.634309e+12       1.634309e+12
# 933              gym         0      NaN             NaN                NaN
# 934             -999      -999      NaN             NaN                NaN
# 935             -999      -999      NaN             NaN                NaN
# 936        bike_shop         0  34923.0    1.634309e+12       1.634309e+12
# 937        bike_shop         0      NaN             NaN                NaN
# 938             -999      -999      NaN             NaN                NaN
# 939      music_store         1  35036.0    1.634309e+12       1.634309e+12
# 940      music_store         1      NaN             NaN                NaN
# 941             -999      -999      NaN             NaN                NaN
# 942             -999      -999      NaN             NaN                NaN
# 943   clothing_store         1  35167.0    1.634309e+12       1.634309e+12
# 944   clothing_store         1      NaN             NaN                NaN
# 945             -999      -999      NaN             NaN                NaN
# 946             -999      -999      NaN             NaN                NaN
# 947    jewelry_store         0  35354.0    1.634309e+12       1.634309e+12
# 948    jewelry_store         0      NaN             NaN                NaN
# 949             -999      -999      NaN             NaN                NaN
# 950             -999      -999      NaN             NaN                NaN
# 951           bakery         0  35598.0    1.634309e+12       1.634309e+12
# 952           bakery         0      NaN             NaN                NaN
# 953             -999      -999      NaN             NaN                NaN
# 954       craft_shop         1  35683.0    1.634309e+12       1.634309e+12
# 955       craft_shop         1      NaN             NaN                NaN
# 956             -999      -999      NaN             NaN                NaN
# 957             -999      -999      NaN             NaN                NaN
# 958         pizzeria         1  35830.0    1.634309e+12       1.634309e+12
# 959         pizzeria         1      NaN             NaN                NaN
# 960             -999      -999      NaN             NaN                NaN
# 961        pet_store         1  35907.0    1.634309e+12       1.634309e+12
# 962        pet_store         1      NaN             NaN                NaN
# 963             -999      -999      NaN             NaN                NaN
# 964             -999      -999      NaN             NaN                NaN
# 965          florist         1  36038.0    1.634309e+12       1.634309e+12
# 966          florist         1      NaN             NaN                NaN
# 967             -999      -999      NaN             NaN                NaN
# 968             -999      -999      NaN             NaN                NaN
# 969         pharmacy         0  36188.0    1.634309e+12       1.634309e+12
# 970         pharmacy         0      NaN             NaN                NaN
# 971             -999      -999      NaN             NaN                NaN
# 972             -999      -999      NaN             NaN                NaN
# 973      barber_shop         0  36355.0    1.634309e+12       1.634309e+12
# 974      barber_shop         0      NaN             NaN                NaN
# 975             -999      -999      NaN             NaN                NaN
# 976             -999      -999      NaN             NaN                NaN
# 977             cafe         0  36541.0    1.634309e+12       1.634309e+12
# 978             cafe         0      NaN             NaN                NaN
# 979             -999      -999      NaN             NaN                NaN
# 980             -999      -999      NaN             NaN                NaN
# 981      music_store      -999      NaN             NaN                NaN
# 982   clothing_store      -999      NaN             NaN                NaN
# 983        pet_store      -999      NaN             NaN                NaN
# 984         pizzeria      -999      NaN             NaN                NaN
# 985       craft_shop      -999      NaN             NaN                NaN
# 986        bike_shop      -999      NaN             NaN                NaN
# 987             -999      -999      NaN             NaN                NaN
# 988             -999      -999      NaN             NaN                NaN
# 989          florist      -999      NaN             NaN                NaN
# 990             -999      -999      NaN             NaN                NaN
# 991             -999      -999      NaN             NaN                NaN
# 992      barber_shop      -999  37642.0    1.634309e+12       1.634309e+12
# 993      barber_shop      -999      NaN             NaN                NaN
# 994             -999      -999      NaN             NaN                NaN
# 995             -999      -999      NaN             NaN                NaN
# 996             -999      -999      NaN             NaN                NaN
# 997    jewelry_store      -999  37706.0    1.634309e+12       1.634309e+12
# 998    jewelry_store      -999      NaN             NaN                NaN
# 999             -999      -999      NaN             NaN                NaN
# 1000            -999      -999      NaN             NaN                NaN
# 1001          bakery      -999  37745.0    1.634309e+12       1.634309e+12
# 1002          bakery      -999      NaN             NaN                NaN
# 1003            -999      -999      NaN             NaN                NaN
# 1004            -999      -999      NaN             NaN                NaN
# 1005        pharmacy      -999  37809.0    1.634309e+12       1.634309e+12
# 1006        pharmacy      -999      NaN             NaN                NaN
# 1007            -999      -999      NaN             NaN                NaN
# 1008            -999      -999      NaN             NaN                NaN
# 1009       toy_store      -999  37874.0    1.634309e+12       1.634309e+12
# 1010       toy_store      -999      NaN             NaN                NaN
# 1011            -999      -999      NaN             NaN                NaN
# 1012            -999      -999      NaN             NaN                NaN
# 1013   grocery_store      -999  37928.0    1.634309e+12       1.634309e+12
# 1014   grocery_store      -999      NaN             NaN                NaN
# 1015            -999      -999      NaN             NaN                NaN
# 1016            -999      -999      NaN             NaN                NaN
# 1017      craft_shop      -999  37976.0    1.634309e+12       1.634309e+12
# 1018      craft_shop      -999      NaN             NaN                NaN
# 1019            -999      -999      NaN             NaN                NaN
# 1020            -999      -999      NaN             NaN                NaN
# 1021  clothing_store      -999  38036.0    1.634309e+12       1.634309e+12
# 1022  clothing_store      -999      NaN             NaN                NaN
# 1023            -999      -999      NaN             NaN                NaN
# 1024            -999      -999      NaN             NaN                NaN
# 1025            cafe      -999  38109.0    1.634309e+12       1.634309e+12
# 1026            cafe      -999      NaN             NaN                NaN
# 1027            -999      -999      NaN             NaN                NaN
# 1028            -999      -999      NaN             NaN                NaN
# 1029            -999      -999      NaN             NaN                NaN
# 1030             gym      -999  38163.0    1.634309e+12       1.634309e+12
# 1031             gym      -999      NaN             NaN                NaN
# 1032            -999      -999      NaN             NaN                NaN
# 1033            -999      -999      NaN             NaN                NaN
# 1034       pet_store      -999  38214.0    1.634309e+12       1.634309e+12
# 1035       pet_store      -999      NaN             NaN                NaN
# 1036            -999      -999      NaN             NaN                NaN
# 1037            -999      -999      NaN             NaN                NaN
# 1038            -999      -999      NaN             NaN                NaN
# 1039        pizzeria      -999  38289.0    1.634309e+12       1.634309e+12
# 1040        pizzeria      -999      NaN             NaN                NaN
# 1041            -999      -999      NaN             NaN                NaN
# 1042            -999      -999      NaN             NaN                NaN
# 1043            -999      -999      NaN             NaN                NaN
# 1044     music_store      -999  38330.0    1.634309e+12       1.634309e+12
# 1045     music_store      -999      NaN             NaN                NaN
# 1046            -999      -999      NaN             NaN                NaN
# 1047            -999      -999      NaN             NaN                NaN
# 1048       bike_shop      -999  38395.0    1.634309e+12       1.634309e+12
# 1049       bike_shop      -999      NaN             NaN                NaN
# 1050            -999      -999      NaN             NaN                NaN
# 1051            -999      -999      NaN             NaN                NaN
# 1052         florist      -999  38465.0    1.634309e+12       1.634309e+12
# 1053         florist      -999      NaN             NaN                NaN
#
#       eeg collection duration  classifier duration normalized  result  \
# 854                       2.0             0.202779       True     0.0
# 855                       NaN                  NaN        NaN     NaN
# 856                       NaN                  NaN        NaN     NaN
# 857                       NaN                  NaN        NaN     NaN
# 858                       2.0             0.221186       True     0.0
# 859                       NaN                  NaN        NaN     NaN
# 1046                      NaN                  NaN        NaN     NaN
# 1047                      NaN                  NaN        NaN     NaN
# 1048                      2.0             0.182918       True     0.0
# 1049                      NaN                  NaN        NaN     NaN
# 1050                      NaN                  NaN        NaN     NaN
# 1051                      NaN                  NaN        NaN     NaN
# 1052                      2.0             0.184867       True     0.0
# 1053                      NaN                  NaN        NaN     NaN
#
#       probability        next_type  orig_eegoffset   diff  big_diff
# 854      0.498679     CUED_REC_CUE       8540117.0  204.0     False
# 855           NaN    CUED_REC_STOP             NaN    NaN     False
# 856           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 857           NaN       CLASSIFIER             NaN    NaN     False
# 858      0.432233     CUED_REC_CUE       8556123.0  222.0     False
# 859           NaN    CUED_REC_WORD             NaN    NaN     False
# 860           NaN    CUED_REC_STOP             NaN    NaN     False
# 861           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 862           NaN       CLASSIFIER             NaN    NaN     False
# 863      0.438787     CUED_REC_CUE       8572574.0  209.0     False
# 864           NaN    CUED_REC_WORD             NaN    NaN     False
# 865           NaN    CUED_REC_STOP             NaN    NaN     False
# 866           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 867           NaN       CLASSIFIER             NaN    NaN     False
# 868      0.444551     CUED_REC_CUE       8588991.0  186.0     False
# 869           NaN    CUED_REC_WORD             NaN    NaN     False
# 870           NaN    CUED_REC_STOP             NaN    NaN     False
# 871           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 872           NaN       CLASSIFIER             NaN    NaN     False
# 873      0.451440     CUED_REC_CUE       8601483.0  212.0     False
# 874           NaN    CUED_REC_WORD             NaN    NaN     False
# 875           NaN    CUED_REC_STOP             NaN    NaN     False
# 876           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 877           NaN       CLASSIFIER             NaN    NaN     False
# 878      0.462814     CUED_REC_CUE       8617968.0  190.0     False
# 879           NaN    CUED_REC_WORD             NaN    NaN     False
# 880           NaN    CUED_REC_STOP             NaN    NaN     False
# 881           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 882           NaN       CLASSIFIER             NaN    NaN     False
# 883      0.471214     CUED_REC_CUE       8631314.0  194.0     False
# 884           NaN    CUED_REC_WORD             NaN    NaN     False
# 885           NaN    CUED_REC_STOP             NaN    NaN     False
# 886           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 887           NaN       CLASSIFIER             NaN    NaN     False
# 888      0.444087     CUED_REC_CUE       8640872.0  194.0     False
# 889           NaN    CUED_REC_STOP             NaN    NaN     False
# 890           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 891           NaN       CLASSIFIER             NaN    NaN     False
# 892      0.489838     CUED_REC_CUE       8655137.0  201.0     False
# 893           NaN    CUED_REC_STOP             NaN    NaN     False
# 894           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 895           NaN       CLASSIFIER             NaN    NaN     False
# 896      0.494169     CUED_REC_CUE       8671587.0  178.0     False
# 897           NaN    CUED_REC_WORD             NaN    NaN     False
# 898           NaN    CUED_REC_STOP             NaN    NaN     False
# 899           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 900           NaN       CLASSIFIER             NaN    NaN     False
# 901      0.460775     CUED_REC_CUE       8682134.0  184.0     False
# 902           NaN    CUED_REC_WORD             NaN    NaN     False
# 903           NaN    CUED_REC_STOP             NaN    NaN     False
# 904           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 905           NaN       CLASSIFIER             NaN    NaN     False
# 906      0.475737     CUED_REC_CUE       8698554.0  190.0     False
# 907           NaN    CUED_REC_WORD             NaN    NaN     False
# 908           NaN    CUED_REC_STOP             NaN    NaN     False
# 909           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 910           NaN       CLASSIFIER             NaN    NaN     False
# 911      0.447627     CUED_REC_CUE       8715004.0  172.0     False
# 912           NaN    CUED_REC_STOP             NaN    NaN     False
# 913           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 914           NaN       CLASSIFIER             NaN    NaN     False
# 915      0.490428     CUED_REC_CUE       8725208.0  196.0     False
# 916           NaN    CUED_REC_STOP             NaN    NaN     False
# 917           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 918           NaN       CLASSIFIER             NaN    NaN     False
# 919      0.499522     CUED_REC_CUE       8742068.0  176.0     False
# 920           NaN    CUED_REC_STOP             NaN    NaN     False
# 921           NaN      TRIAL_START             NaN    NaN     False
# 922           NaN       POINTER_ON             NaN    NaN     False
# 923           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 924           NaN       CLASSIFIER             NaN    NaN     False
# 925      0.499500             WORD       8805110.0  178.0     False
# 926           NaN       POINTER_ON             NaN    NaN     False
# 927           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 928           NaN       CLASSIFIER             NaN    NaN     False
# 929      0.483932             WORD       8862210.0  196.0     False
# 930           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 931           NaN       CLASSIFIER             NaN    NaN     False
# 932      0.483072             WORD       8873950.0  177.0     False
# 933           NaN       POINTER_ON             NaN    NaN     False
# 934           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 935           NaN       CLASSIFIER             NaN    NaN     False
# 936      0.483846             WORD       8956684.0  179.0     False
# 937           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 938           NaN       CLASSIFIER             NaN    NaN     False
# 939      0.476489             WORD       8985491.0  183.0     False
# 940           NaN       POINTER_ON             NaN    NaN     False
# 941           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 942           NaN       CLASSIFIER             NaN    NaN     False
# 943      0.493072             WORD       9019143.0  183.0     False
# 944           NaN       POINTER_ON             NaN    NaN     False
# 945           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 946           NaN       CLASSIFIER             NaN    NaN     False
# 947      0.499571             WORD       9066961.0  190.0     False
# 948           NaN       POINTER_ON             NaN    NaN     False
# 949           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 950           NaN       CLASSIFIER             NaN    NaN     False
# 951      0.494937             WORD       9129455.0  176.0     False
# 952           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 953           NaN       CLASSIFIER             NaN    NaN     False
# 954      0.471460             WORD       9151162.0  181.0     False
# 955           NaN       POINTER_ON             NaN    NaN     False
# 956           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 957           NaN       CLASSIFIER             NaN    NaN     False
# 958      0.484940             WORD       9188843.0  190.0     False
# 959           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 960           NaN       CLASSIFIER             NaN    NaN     False
# 961      0.494563             WORD       9208639.0  181.0     False
# 962           NaN       POINTER_ON             NaN    NaN     False
# 963           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 964           NaN       CLASSIFIER             NaN    NaN     False
# 965      0.493555             WORD       9241950.0  209.0     False
# 966           NaN       POINTER_ON             NaN    NaN     False
# 967           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 968           NaN       CLASSIFIER             NaN    NaN     False
# 969      0.486845             WORD       9280552.0  301.0     False
# 970           NaN       POINTER_ON             NaN    NaN     False
# 971           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 972           NaN       CLASSIFIER             NaN    NaN     False
# 973      0.492887             WORD       9323147.0  184.0     False
# 974           NaN       POINTER_ON             NaN    NaN     False
# 975           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 976           NaN       CLASSIFIER             NaN    NaN     False
# 977      0.497103             WORD       9370932.0  176.0     False
# 978           NaN        TRIAL_END             NaN    NaN     False
# 979           NaN        REC_START             NaN    NaN     False
# 980           NaN         REC_WORD             NaN    NaN     False
# 981           NaN         REC_WORD             NaN    NaN     False
# 982           NaN         REC_WORD             NaN    NaN     False
# 983           NaN         REC_WORD             NaN    NaN     False
# 984           NaN         REC_WORD             NaN    NaN     False
# 985           NaN         REC_WORD             NaN    NaN     False
# 986           NaN         EFR_MARK             NaN    NaN     False
# 987           NaN         EFR_MARK             NaN    NaN     False
# 988           NaN         REC_WORD             NaN    NaN     False
# 989           NaN         REC_STOP             NaN    NaN     False
# 990           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 991           NaN       CLASSIFIER             NaN    NaN     False
# 992      0.454916     CUED_REC_CUE       9652612.0  219.0     False
# 993           NaN    CUED_REC_WORD             NaN    NaN     False
# 994           NaN    CUED_REC_STOP             NaN    NaN     False
# 995           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 996           NaN       CLASSIFIER             NaN    NaN     False
# 997      0.439279     CUED_REC_CUE       9669064.0  180.0     False
# 998           NaN    CUED_REC_STOP             NaN    NaN     False
# 999           NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1000          NaN       CLASSIFIER             NaN    NaN     False
# 1001     0.480211     CUED_REC_CUE       9679029.0  173.0     False
# 1002          NaN    CUED_REC_STOP             NaN    NaN     False
# 1003          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1004          NaN       CLASSIFIER             NaN    NaN     False
# 1005     0.490138     CUED_REC_CUE       9695482.0  213.0     False
# 1006          NaN    CUED_REC_STOP             NaN    NaN     False
# 1007          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1008          NaN       CLASSIFIER             NaN    NaN     False
# 1009     0.495486     CUED_REC_CUE       9712172.0  205.0     False
# 1010          NaN    CUED_REC_STOP             NaN    NaN     False
# 1011          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1012          NaN       CLASSIFIER             NaN    NaN     False
# 1013     0.457771     CUED_REC_CUE       9725925.0  181.0     False
# 1014          NaN    CUED_REC_STOP             NaN    NaN     False
# 1015          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1016          NaN       CLASSIFIER             NaN    NaN     False
# 1017     0.504884     CUED_REC_CUE       9738145.0  185.0     False
# 1018          NaN    CUED_REC_STOP             NaN    NaN     False
# 1019          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1020          NaN       CLASSIFIER             NaN    NaN     False
# 1021     0.496027     CUED_REC_CUE       9753536.0  221.0     False
# 1022          NaN    CUED_REC_STOP             NaN    NaN     False
# 1023          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1024          NaN       CLASSIFIER             NaN    NaN     False
# 1025     0.498006     CUED_REC_CUE       9772242.0  215.0     False
# 1026          NaN    CUED_REC_WORD             NaN    NaN     False
# 1027          NaN    CUED_REC_STOP             NaN    NaN     False
# 1028          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1029          NaN       CLASSIFIER             NaN    NaN     False
# 1030     0.464269     CUED_REC_CUE       9786132.0  171.0     False
# 1031          NaN    CUED_REC_STOP             NaN    NaN     False
# 1032          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1033          NaN       CLASSIFIER             NaN    NaN     False
# 1034     0.484723     CUED_REC_CUE       9799173.0  183.0     False
# 1035          NaN    CUED_REC_WORD             NaN    NaN     False
# 1036          NaN    CUED_REC_STOP             NaN    NaN     False
# 1037          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1038          NaN       CLASSIFIER             NaN    NaN     False
# 1039     0.493645     CUED_REC_CUE       9818318.0  181.0     False
# 1040          NaN    CUED_REC_WORD             NaN    NaN     False
# 1041          NaN    CUED_REC_STOP             NaN    NaN     False
# 1042          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1043          NaN       CLASSIFIER             NaN    NaN     False
# 1044     0.498585     CUED_REC_CUE       9828832.0  174.0     False
# 1045          NaN    CUED_REC_STOP             NaN    NaN     False
# 1046          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1047          NaN       CLASSIFIER             NaN    NaN     False
# 1048     0.481649     CUED_REC_CUE       9845350.0  184.0     False
# 1049          NaN    CUED_REC_STOP             NaN    NaN     False
# 1050          NaN  CLASSIFIER_WAIT             NaN    NaN     False
# 1051          NaN       CLASSIFIER             NaN    NaN     False
# 1052     0.498351     CUED_REC_CUE       9863406.0  185.0     False
# 1053          NaN    CUED_REC_STOP             NaN    NaN     False

# %% [markdown]
# ### Very large gaps between eeg collection and classifier result

# %%
CL_evs["diff"] = CL_evs["time_class_result"]-CL_evs["time_eeg_epoch"]
CL_evs["overtime"] = CL_evs["classifier duration"]>6

# %%
CL_evs[["diff", "classifier duration", "type"]].dropna()
# Out:
#          diff  classifier duration        type
# 93      171.0             0.171522  CLASSIFIER
# 97      172.0             0.171078  CLASSIFIER
# 101     173.0             0.172517  CLASSIFIER
# 105     170.0             0.170400  CLASSIFIER
# 108     169.0             0.168759  CLASSIFIER
# ...       ...                  ...         ...
# 103304  204.0             0.203262  CLASSIFIER
# 103309  182.0             0.180348  CLASSIFIER
# 103314  168.0             0.167918  CLASSIFIER
# 103318  171.0             0.170764  CLASSIFIER
# 103323  214.0             0.212920  CLASSIFIER
#
# [13114 rows x 3 columns]

# %%
plt.figure(figsize=(8,4))
sns.histplot(CL_evs.dropna(subset=["diff"]),
             x='diff', stat='probability', binwidth=20, hue='trial_type')
plt.xlim(0, 1000)
plt.xlabel('Classifier Compute Time (ms)')
plt.savefig("classifier_compute_times.pdf", dpi=200)

# %%
pd.options.display.float_format = '{:.3f}'.format
performance_stats = CL_evs.query("type=='CLASSIFIER' and next_type=='WORD'").groupby(["subject", "session"]).agg(
    {"classifier duration":["mean", "median", "max"], "overtime":["sum", "count", "mean"]}
)
performance_stats['bad_session'] = performance_stats['overtime']['mean']>=.05
performance_stats.to_csv("system_performance_stats_FR_only.csv")
performance_stats
# Out:
#                 classifier duration              overtime              \
#                                mean median   max      sum count  mean
# subject session
# LTP462  0                     0.207  0.185 1.367        0   114 0.000
#         1                     0.193  0.185 0.337        0   106 0.000
# LTP468  0                     0.212  0.197 0.440        0    88 0.000
#         1                     0.190  0.181 0.444        0    98 0.000
# LTP470  0                     0.215  0.202 0.506        0    88 0.000
# ...                             ...    ...   ...      ...   ...   ...
# LTP498  3                     0.195  0.188 0.363        0    89 0.000
# LTP500  0                     0.203  0.192 0.434        0    92 0.000
#         1                     0.215  0.202 0.603        0    94 0.000
#         2                     0.179  0.176 0.236        0    39 0.000
#         3                     0.192  0.185 0.290        0   115 0.000
#
#                 bad_session
#
# subject session
# LTP462  0             False
#         1             False
# LTP468  0             False
#         1             False
# LTP470  0             False
# ...                     ...
# LTP498  3             False
# LTP500  0             False
#         1             False
#         2             False
#         3             False
#
# [68 rows x 7 columns]

# %%
performance_stats = pd.read_csv("system_performance_stats_FR_only.csv", header=[0, 1], index_col=[0, 1])
performance_stats
# Out:
#                 classifier duration                overtime              \
#                                mean median     max      sum count  mean
# subject session
# LTP462  0                     0.207  0.185   1.367        0   114 0.000
# LTP498  0                     0.230  0.200   0.800        0    81 0.000
#         1                    21.990  0.449  76.028       53   117 0.453
#         2                     0.192  0.181   0.641        0   108 0.000
#         3                     0.195  0.188   0.363        0    89 0.000
# LTP500  0                     0.203  0.192   0.434        0    92 0.000
#         1                     0.215  0.202   0.603        0    94 0.000
#         2                     0.179  0.176   0.236        0    39 0.000
#         3                     0.192  0.185   0.290        0   115 0.000
#
#                        bad_session
#                 Unnamed: 8_level_1
# subject session
# LTP462  0                    False
#         1                    False
# LTP468  0                    False
#         1                    False
# LTP470  0                    False
#         1                    False
# LTP473  0                    False
#         1                    False
# LTP474  0                    False
#         1                    False
# LTP475  0                    False
#         1                    False
# LTP476  0                    False
#         1                    False
# LTP477  0                    False
#         1                    False
# LTP478  0                    False
#         1                     True
#         2                    False
#         3                     True
# LTP479  0                    False
#         1                    False
#         2                     True
#         3                     True
# LTP481  0                    False
#         1                    False
#         2                     True
#         3                    False
# LTP484  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP486  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP488  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP493  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP494  0                    False
#         1                    False
#         2                     True
#         3                    False
# LTP495  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP496  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP497  0                    False
#         1                    False
#         2                    False
#         3                    False
# LTP498  0                    False
#         1                     True
#         2                    False
#         3                    False
# LTP500  0                    False
#         1                    False
#         2                    False
#         3                    False

# %%
with open("performance_stats.tex", "w") as f:
    f.write(performance_stats.to_latex(float_format="%.3f", longtable=True, 
                                       label="system_perfomance",
                                       caption="\textbf{System Performance} Data for each subject and session in the closed loop dataset, detailing how long computation of classifier predictions lasted and whether or not the duration of that computation exceeded our tolerance threshold of 6 seconds (the maximum compute time that would still allow the prediction to be actionable)"))

# %%
performance_stats.to_latex?
# Out:
# Signature:
# performance_stats.to_latex(
#     buf=None,
#     columns=None,
#     col_space=None,
#     header=True,
#     index=True,
#     na_rep='NaN',
#     formatters=None,
#     float_format=None,
#     sparsify=None,
#     index_names=True,
#     bold_rows=False,
#     column_format=None,
#     longtable=None,
#     escape=None,
#     encoding=None,
#     decimal='.',
#     multicolumn=None,
#     multicolumn_format=None,
#     multirow=None,
#     caption=None,
#     label=None,
#     position=None,
# )
# Docstring:
# Render object to a LaTeX tabular, longtable, or nested table.
#
# Requires ``\usepackage{booktabs}``.  The output can be copy/pasted
# into a main LaTeX document or read from an external file
# with ``\input{table.tex}``.
#
# .. versionchanged:: 1.0.0
#    Added caption and label arguments.
#
# .. versionchanged:: 1.2.0
#    Added position argument, changed meaning of caption argument.
#
# Parameters
# ----------
# buf : str, Path or StringIO-like, optional, default None
#     Buffer to write to. If None, the output is returned as a string.
# columns : list of label, optional
#     The subset of columns to write. Writes all columns by default.
# col_space : int, optional
#     The minimum width of each column.
# header : bool or list of str, default True
#     Write out the column names. If a list of strings is given,
#     it is assumed to be aliases for the column names.
# index : bool, default True
#     Write row names (index).
# na_rep : str, default 'NaN'
#     Missing data representation.
# formatters : list of functions or dict of {str: function}, optional
#     Formatter functions to apply to columns' elements by position or
#     name. The result of each function must be a unicode string.
#     List must be of length equal to the number of columns.
# float_format : one-parameter function or str, optional, default None
#     Formatter for floating point numbers. For example
#     ``float_format="%.2f"`` and ``float_format="{:0.2f}".format`` will
#     both result in 0.1234 being formatted as 0.12.
# sparsify : bool, optional
#     Set to False for a DataFrame with a hierarchical index to print
#     every multiindex key at each row. By default, the value will be
#     read from the config module.
# index_names : bool, default True
#     Prints the names of the indexes.
# bold_rows : bool, default False
#     Make the row labels bold in the output.
# column_format : str, optional
#     The columns format as specified in `LaTeX table format
#     <https://en.wikibooks.org/wiki/LaTeX/Tables>`__ e.g. 'rcl' for 3
#     columns. By default, 'l' will be used for all columns except
#     columns of numbers, which default to 'r'.
# longtable : bool, optional
#     By default, the value will be read from the pandas config
#     module. Use a longtable environment instead of tabular. Requires
#     adding a \usepackage{longtable} to your LaTeX preamble.
# escape : bool, optional
#     By default, the value will be read from the pandas config
#     module. When set to False prevents from escaping latex special
#     characters in column names.
# encoding : str, optional
#     A string representing the encoding to use in the output file,
#     defaults to 'utf-8'.
# decimal : str, default '.'
#     Character recognized as decimal separator, e.g. ',' in Europe.
# multicolumn : bool, default True
#     Use \multicolumn to enhance MultiIndex columns.
#     The default will be read from the config module.
# multicolumn_format : str, default 'l'
#     The alignment for multicolumns, similar to `column_format`
#     The default will be read from the config module.
# multirow : bool, default False
#     Use \multirow to enhance MultiIndex rows. Requires adding a
#     \usepackage{multirow} to your LaTeX preamble. Will print
#     centered labels (instead of top-aligned) across the contained
#     rows, separating groups via clines. The default will be read
#     from the pandas config module.
# caption : str or tuple, optional
#     Tuple (full_caption, short_caption),
#     which results in ``\caption[short_caption]{full_caption}``;
#     if a single string is passed, no short caption will be set.
#
#     .. versionadded:: 1.0.0
#
#     .. versionchanged:: 1.2.0
#        Optionally allow caption to be a tuple ``(full_caption, short_caption)``.
#
# label : str, optional
#     The LaTeX label to be placed inside ``\label{}`` in the output.
#     This is used with ``\ref{}`` in the main ``.tex`` file.
#
#     .. versionadded:: 1.0.0
# position : str, optional
#     The LaTeX positional argument for tables, to be placed after
#     ``\begin{}`` in the output.
#
#     .. versionadded:: 1.2.0
#
#         Returns
#         -------
#         str or None
#             If buf is None, returns the result as a string. Otherwise returns
#             None.
#
# See Also
# --------
# Styler.to_latex : Render a DataFrame to LaTeX with conditional formatting.
# DataFrame.to_string : Render a DataFrame to a console-friendly
#     tabular output.
# DataFrame.to_html : Render a DataFrame as an HTML table.
#
# Examples
# --------
# >>> df = pd.DataFrame(dict(name=['Raphael', 'Donatello'],
# ...                   mask=['red', 'purple'],
# ...                   weapon=['sai', 'bo staff']))
# >>> print(df.to_latex(index=False))  # doctest: +SKIP
# \begin{tabular}{lll}
#  \toprule
#        name &    mask &    weapon \\
#  \midrule
#     Raphael &     red &       sai \\
#   Donatello &  purple &  bo staff \\
# \bottomrule
# \end{tabular}
# File:      ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py
# Type:      method
